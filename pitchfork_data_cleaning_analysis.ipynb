# %%
# Combined all primary and necessary functions and code in 1 notebook

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re
import numpy as np

# %%
# ALBUM REVIEW URL SCRAPING

# get ALL urls from pages 1-2006

# empty list
url_lst = []

# for loop get all pages
for x in range(0,2006):
    url = f"https://pitchfork.com/reviews/albums/?page={x+1}"
    
    html = requests.get(url).content
    soup = bs(html)
    
    urls = ["https://pitchfork.com" + j.get('href') for j in soup.select("div.review > a")]
    url_lst.append(urls)

# list flattening to prepare for df
flat_list = [i for j in url_lst for i in j]

# df conversion
df = pd.DataFrame(flat_list)
df.drop(columns="Unnamed: 0", axis=1, inplace=True)

# df to csv file and checking
df.to_csv('album_review_urls_4.csv')
pd.read_csv('album_review_urls_4.csv')

# %%
# REPLACE NULL VALUES FUNCTIONS

# key for album_rating function
rating_key = "div.score-circle > span.score"

# album_rating function
def rating_extract(soup, key):
    parse = soup.select(key)
    if parse == []:
        return np.nan
    else:
        return parse[0].text

# key for album_name function
album_name_key = "h1"

# album_name function
def album_name_extract(soup, key):
    parse = soup.select(key)
    if parse == []:
        return np.nan
    else:
        return parse[0].text

# key for artist_name function
artist_name_key = "h2"

# artist_name function
def artist_name_extract(soup, key):
    parse = soup.select(key)
    if parse == []:
        return np.nan
    else:
        return parse[0].text

# key for album_year function
year_key = "span.single-album-tombstone__meta-year"

# album_year function
def year_extract(soup, key):
    parse = soup.select(key)
    pattern = r"\d+"
    parse2 = re.findall(pattern, parse[0].text)
    if parse2 == []:
        return np.nan
    else:
        return parse2[0]

# key for record_label function
label_key = "li.labels-list__item"

# record_label function
def label_extract(soup, key):
    parse = soup.select(key)
    if parse == []:
        return np.nan
    else:
        return parse[0].text

# %%
# FINAL WEB SCRAPING CODE
# need to check new length of urls list to determine the range for for loop

# empty lists
album_ratings_lst = []
album_names_lst = []
artist_names_lst = []
album_years_lst = []
record_labels_lst = []
    
# url list
album_review_urls_df = pd.read_csv('album_review_urls_3.csv')
album_review_urls_df.drop(columns="Unnamed: 0", axis=1, inplace=True)
album_review_urls_lst = list(album_review_urls_df["0"])
urls = album_review_urls_lst

for x in range(0,300):
    html = requests.get(urls[x]).content
    soup = bs(html)
    
    # album ratings
    album_ratings = rating_extract(soup, rating_key)
    album_ratings_lst.append(album_ratings)
    
    # album names
    album_names = album_name_extract(soup, album_name_key)
    album_names_lst.append(album_names)
    
    # artist names
    artist_names = artist_name_extract(soup, artist_name_key)
    artist_names_lst.append(artist_names)
    
    # album years
    album_years = year_extract(soup, year_key)
    album_years_lst.append(album_years)
    
    # record labels
    record_labels = label_extract(soup, label_key)
    record_labels_lst.append(record_labels)
    
print(len(album_ratings_lst))
print(len(album_names_lst))
print(len(artist_names_lst))
print(len(album_years_lst))
print(len(record_labels_lst))
# Out:
# 300
# 300
# 300
# 300
# 300

# %%
print(album_ratings_lst)
print(album_names_lst)
print(artist_names_lst)
print(album_years_lst)
print(record_labels_lst)
# Out:
# ['9.2', '7.4', '8.0', '6.8', '8.5', '6.6', '7.5', '7.7', '7.4', '7.5', '7.2', '7.4', '3.6', '7.7', '7.6', '7.8', '8.2', '7.3', '7.5', '6.4', '7.5', '7.8', '8.4', '8.0', '7.8', '5.7', '7.3', '8.0', '7.4', '7.6', '9.4', '7.8', '5.0', '7.3', '8.2', '7.8', '7.4', '7.2', '7.6', '7.4', '7.6', '7.4', '8.4', '8.4', '7.7', '6.8', '7.8', '7.4', '7.1', '6.9', '7.5', '8.0', '7.0', '3.6', '7.6', '7.3', '8.0', '7.4', '7.0', '6.3', '5.6', '7.0', '7.5', '7.8', '7.4', '9.1', '7.3', '7.0', '6.3', '7.9', '5.1', '8.0', '6.8', '7.5', '6.8', '7.2', '6.6', '7.4', '7.7', '5.5', '7.4', '7.2', '8.0', '8.0', '7.2', '7.7', '7.5', '7.3', '6.6', '7.7', '6.9', '6.8', '7.6', '7.5', '7.1', '7.4', '6.8', '4.9', '8.0', '7.5']
# ['Kid A Mnesia', 'Voyage', 'Raw Demoon Alchemy (A Lone Operation)', 'Arm’s Length EP', 'Valentine', 'Projector', 'HOUSE OF CONFUSION', 'Pohorylle', 'Something for Thee Hotties', 'The Path of the Clouds', 'Candy Racer', 'Soul Controller', '=', 'Lily We Need to Talk Now', 'Mandatory Enjoyment', 'Reticence / Resistance', 'im hole', 'Collected Pieces II', 'Intra-I', 'Extropy', 'Come On Over', 'Petunia', 'I Don’t Live Here Anymore', 'Far In', 'Quivering in Time', 'Hushed and Grim', 'LP!', 'B-Sides & Rarities (Part II)', 'Love Black', 'Crossover EP', 'A Love Supreme: Live in Seattle', 'Fun House', 'My Morning Jacket', 'Actually, You Can', 'Shade', '-io', 'Lull', 'Is It Time to Eat the Rich Yet?', 'Sympathy for Life', 'Big Bend (An Original Soundtrack for Public Television)', 'Source ⧺ We Move', 'Ookii Gekkou', 'Combat Rock', 'Una Rosa', 'Blue Banisters', 'Fast Idol', 'Heartbeats', 'City of Mirrors', 'Punk', 'DJ-Kicks', 'A Tear in the Fabric of Life', 'Chameleon', 'Simple, Sweet, and Smiling', 'shut the fuck up talking to me', 'Eternal Home', 'Wayfinder', 'Weight of the World', 'Pins and Needles', 'Juno', 'High Dragon and Universe', 'Optimist', 'Georgia Blue', 'Sediments We Move', 'All Hours EP', 'Seal', 'Let It Be (Super Deluxe)\xa0', 'to hell with it', 'A Night at the Little Los Angeles', 'Trying Not to Think About It', 'Why Do Birds Sing? (Deluxe Edition)', 'Music of the Spheres', 'Mercurial World', 'Ekphrasis', 'I Want the Door to Open', 'Illusory Walls', 'Life of a DON', 'Seventeen Going Under', 'Garden of Burning Apparitions', 'Geist', 'then i’ll be happy EP', 'Floating Mountains', 'Piecework', 'Talk Memory', 'Amanita (25th Anniversary Edition)', 'True Love', 'Crimson Poem', 'Crash', 'One Touch (20th Anniversary Edition)', 'Friends That Break Your Heart', 'Vol. 3', 'Cacerolazo', 'Melodi', 'All Day Gentle Hold !', 'CXXI', 'one hand on the steering wheel the other sewing a garden', 'Mod Prog Sic', 'Expensive Pain', 'Trust Fund Babies', 'Ma délire - Songs of love, lost & found', 'Only the End']
# ['Radiohead', 'ABBA', 'Darius Jones', 'Leo Bhanji', 'Snail Mail', 'Geese', 'Trace Mountains', 'Margo Cilker', 'Megan Thee Stallion', 'Marissa Nadler', 'Kyary Pamyu Pamyu', 'AK Bandamont', 'Ed Sheeran', 'Lily Konigsberg', 'Dummy', 'Pelt', 'aya', 'Mary Lattimore', 'Theon Cross', 'Markus Guentner', 'Shania Twain', 'Tonstartssbandht', 'The War on Drugs', 'Helado Negro', 'Eris Drew', 'Mastodon', 'JPEGMAFIA', 'Nick Cave & the Bad Seeds', 'Bktherula', 'Dua Saleh', 'John Coltrane', 'Hand Habits', 'My Morning Jacket', 'Deerhoof', 'Grouper', 'Circuit des Yeux', 'Jessica Pavone', 'The F16s', 'Parquet Courts', 'Explosions in the Sky', 'Nubya Garcia', 'Vanishing Twin', 'The Clash', 'Xenia Rubinos', 'Lana Del Rey', 'Black Marble', 'UNIIQU3', 'Dos Santos', 'Young Thug', 'Disclosure', 'Knocked Loose', 'Anthony Naples', 'Kacy Hill', 'Zack Fox', 'Fire-Toolz', 'Boy Scouts', 'Maxo Kream', 'Natalie Hemby', 'Remi Wolf', 'Alice Longyu Gao', 'FINNEAS', 'Jason Isbell and the 400 Unit', 'Charlotte Greve', 'Anz', 'Seal', 'The Beatles', 'PinkPantheress', 'Kevin Morby', 'JoJo', 'Violent Femmes', 'Coldplay', 'Magdalena Bay', 'Bronze NazarethRoc Marciano', 'Lala Lala ', 'The World Is a Beautiful Place & I Am No Longer Afraid to Die', 'Don Toliver', 'Sam Fender', 'Full of Hell', 'Shannon Lay ', 'Glaiveericdoa', 'Soshi Takeda', 'Kowloon Walled City', 'BADBADNOTGOOD', 'Bardo Pond', 'Hovvdy', 'Yikii', 'Dave Matthews Band', 'Sugababes', 'James Blake', 'Topdown Dialectic', 'Nick Zanca', 'Kit Sebastian', 'Porches', 'Richard Youngs', 'Ada Lea', 'Black Dice', 'Meek Mill', 'Lil WayneRich the Kid', 'Myriam Gendron', 'Ashley Shadow']
# ['2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '1997', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', nan, '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '1982', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '1991', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '1996', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021']
# ['XL', 'Capitol', 'Northern Spy', 'Dirty Hit', 'Matador', 'Partisan', 'Lame-O', 'Fluff and Gravy', [nan], 'Sacred Bones', 'KRK Lab', 'MoneyGettingBrothers', 'Atlantic', 'Wharf Cat', 'Trouble in Mind', 'Three Lobed', 'Hyperdub', 'Ghostly International', 'Marathon Artists', 'A Strangely Isolated Place', 'Mercury', 'Mexican Summer', 'Atlantic', '4AD', 'T4T LUV NRG', 'Reprise', 'EQT', 'Mute', 'Warner', 'AGAINST GIANTS', 'Impulse!', 'Saddle Creek', 'ATO', 'Joyful Noise', 'Kranky', 'Matador', 'Chaikin', 'House Arrest', 'Rough Trade', 'Temporary Residence', 'Concord Jazz', 'Fire', 'Sony', 'Anti-', 'Polydor', 'Sacred Bones', 'Local Action', 'International Anthem', '300', '!K7', 'Pure Noise', 'ANS', 'Platoon', 'Parasang', 'Hausu Mountain', 'Anti-', 'Big Persona', 'Fantasy', 'Island', [nan], 'Interscope', 'Southeastern', 'New Amsterdam', 'Ninja Tune', 'ZTT', 'Capitol', 'Parlophone', 'Dead Oceans', 'Clover', 'Craft', 'Atlantic', 'Luminelle', 'Fat Beats', 'Sub Pop', 'Epitaph', 'Cactus Jack', 'Interscope', 'Relapse', 'Sub Pop', 'Listen to the Kids', '100% Silk', 'Neurot', 'XL', 'Matador', 'Grand Jury', 'Danse Noire', 'RCA', 'London', 'Republic', 'Peak Oil', 'Full Spectrum', 'Mr. Bongo', 'Domino', 'Black Truffle', 'Saddle Creek', 'FourFour', 'Maybach Music Group', 'Young Money Entertainment', 'Feeding Tube', 'Felte']

# %%
# create df from all lists and check

final_pitchfork_df = pd.DataFrame({"album_names":album_names_lst, "artist_names":artist_names_lst, "album_years":album_years_lst,
              "record_label":record_labels_lst, "album_ratings":album_ratings_lst})

final_pitchfork_df
# Out:
#                                 album_names     artist_names album_years  \
# 0                              Kid A Mnesia        Radiohead        2021
# 1                                    Voyage             ABBA        2021
# 2     Raw Demoon Alchemy (A Lone Operation)     Darius Jones        2021
# 3                           Arm’s Length EP       Leo Bhanji        2021
# 4                                 Valentine       Snail Mail        2021
# ..                                      ...              ...         ...
# 295           Peppa’s Adventures: The Album        Peppa Pig        2021
# 296  Take the Sadness Out of Saturday Night        Bleachers        2021
# 297                             Crowlink EP  Shirley Collins        2021
# 298              Ngủ Ngày Ngay Ngày Tận Thế     Rắn Cạp Đuôi        2021
# 299                                    Âlem        Altin Gün        2021
#
#      record_label album_ratings
# 0              XL           9.2
# 1         Capitol           7.4
# 2    Northern Spy           8.0
# 3       Dirty Hit           6.8
# 4         Matador           8.5
# ..            ...           ...
# 295          eOne           6.5
# 296           RCA           6.2
# 297        Domino           7.4
# 298       Subtext           7.8
# 299           ATO           7.4
#
# [300 rows x 5 columns]

# %%
final_pitchfork_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   album_names    300 non-null    object
#  1   artist_names   300 non-null    object
#  2   album_years    299 non-null    object
#  3   record_label   296 non-null    object
#  4   album_ratings  300 non-null    object
# dtypes: object(5)
# memory usage: 11.8+ KB

# %%
final_pitchfork_df.describe()
# Out:
#                     album_names     artist_names album_years record_label  \
# count                       300              300         299          296
# unique                      300              296          12          220
# top     I Want the Door to Open  Various Artists        2021   Interscope
# freq                          1                5         286            6
#
#        album_ratings
# count            300
# unique            45
# top              7.4
# freq              29

# %%
# convert ratings into floats

ratings_series = final_pitchfork_df["album_ratings"]

final_pitchfork_df["album_ratings"] = pd.to_numeric(ratings_series, errors="coerce")

# %%
# convert years into integers
# NOT working

years_series = final_pitchfork_df["album_years"]

final_pitchfork_df["album_years"] = pd.to_numeric(years_series, errors="coerce", downcast="integer")

# %%
final_pitchfork_df
# Out:
#                                 album_names     artist_names  album_years  \
# 0                              Kid A Mnesia        Radiohead       2021.0
# 1                                    Voyage             ABBA       2021.0
# 2     Raw Demoon Alchemy (A Lone Operation)     Darius Jones       2021.0
# 3                           Arm’s Length EP       Leo Bhanji       2021.0
# 4                                 Valentine       Snail Mail       2021.0
# ..                                      ...              ...          ...
# 295           Peppa’s Adventures: The Album        Peppa Pig       2021.0
# 296  Take the Sadness Out of Saturday Night        Bleachers       2021.0
# 297                             Crowlink EP  Shirley Collins       2021.0
# 298              Ngủ Ngày Ngay Ngày Tận Thế     Rắn Cạp Đuôi       2021.0
# 299                                    Âlem        Altin Gün       2021.0
#
#      record_label  album_ratings
# 0              XL            9.2
# 1         Capitol            7.4
# 2    Northern Spy            8.0
# 3       Dirty Hit            6.8
# 4         Matador            8.5
# ..            ...            ...
# 295          eOne            6.5
# 296           RCA            6.2
# 297        Domino            7.4
# 298       Subtext            7.8
# 299           ATO            7.4
#
# [300 rows x 5 columns]

# %%
# analysis testing

# artists w/ highest average rating and # of albums
final_pitchfork_df.groupby("artist_names").agg({"album_names": "count","album_ratings": "mean"})
# Out:
#                             album_names  album_ratings
# artist_names
# $uicideboy$                           1            6.7
# ---__--___                            1            7.6
# A Great Big Pile of Leaves            1            7.2
# ABBA                                  1            7.4
# AK Bandamont                          1            7.4
# ...                                 ...            ...
# d’Eon                                 1            7.4
# quickly, quickly                      1            8.1
# quinn                                 1            7.7
# Ænigmatum                             1            7.3
# 박혜진 Park Hye Jin                      1            6.5
#
# [296 rows x 2 columns]

# %%
# analysis testing

# labels with the highest average rating, by # of albums
final_pitchfork_df.groupby("record_label").agg({"album_names": "count","album_ratings": "mean"})
# Out:
#                   album_names  album_ratings
# record_label
# !K7                         1            6.9
# 100% Silk                   1            7.4
# 20 Buck Spin                1            7.3
# 20/20/20                    1            7.2
# 2MR                         1            7.5
# ...                       ...            ...
# ZTT                         1            7.4
# eOne                        1            6.5
# pgLang                      1            6.4
# self-released               4            7.5
# somethingscosmic            1            6.5
#
# [220 rows x 2 columns]

# %%
# analysis testing

# years with the highest average rating, by # of albums
final_pitchfork_df.groupby("album_years").agg({"album_names": "count","album_ratings": "mean"})
# Out:
#              album_names  album_ratings
# album_years
# 1968.0                 1       8.700000
# 1969.0                 1      10.000000
# 1981.0                 1       9.100000
# 1982.0                 1       8.400000
# 1984.0                 1      10.000000
# 1991.0                 1       7.400000
# 1993.0                 1       8.500000
# 1995.0                 1       6.700000
# 1996.0                 2       8.100000
# 1997.0                 2       8.500000
# 2010.0                 1       7.300000
# 2021.0               286       7.240909

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# visualization testing (pandas)

# artists w/ highest average rating and # of albums
final_pitchfork_df.groupby("artist_names").agg({"album_names": "count","album_ratings": "mean"}).plot(kind="scatter", x="album_names", y="album_ratings")

# styling
plt.style.use("classic")
plt.title("Album Ratings by # of Albums", fontsize=24)

plt.xlabel("# of Albums", fontsize=20)
plt.ylabel("Avg Album Rating", fontsize=20)
# Out:
# Text(0, 0.5, 'Avg Album Rating')

# %%
# visualization testing (matplotlib)

# artists w/ highest average rating and # of albums
df1 = final_pitchfork_df.groupby("artist_names").agg({"album_names": "count","album_ratings": "mean"})

#plotting
sns.scatterplot(data=df1, x="album_names", y="album_ratings", style="artist_names", legend=False)

plt.style.use("seaborn-deep")
plt.suptitle("Artist Album Ratings by # of Albums", fontsize=24)
plt.xlabel("# of Albums", fontsize=20)
plt.ylabel("Avg Album Rating", fontsize=20)
# Out:
# Text(0, 0.5, 'Avg Album Rating')

# %%
# visualization testing

# labels with the highest average rating, by # of albums
final_pitchfork_df.groupby("record_label").agg({"album_names": "count","album_ratings": "mean"}).plot(kind="scatter", x="album_names", y="album_ratings")
# Out:
# <AxesSubplot:xlabel='album_names', ylabel='album_ratings'>

# %%
# visualization testing (matplotlib)

# labels with the highest average rating, by # of albums
df2 = final_pitchfork_df.groupby("record_label").agg({"album_names": "count","album_ratings": "mean"})

#plotting
sns.scatterplot(data=df2, x="album_names", y="album_ratings", style="record_label", legend=False)

plt.style.use("seaborn-deep")
plt.suptitle("Label Album Ratings by # of Albums", fontsize=24)
plt.xlabel("# of Albums", fontsize=20)
plt.ylabel("Avg Album Rating", fontsize=20)
# Out:
# Text(0, 0.5, 'Avg Album Rating')

# %%
# visualization testing

# years with the highest average rating, by # of albums
final_pitchfork_df.groupby("album_years").agg({"album_names": "count","album_ratings": "mean"})["album_ratings"].plot(x="album_years")

final_pitchfork_df.groupby("album_years").agg({"album_names": "count","album_ratings": "mean"})["album_names"].plot(secondary_y=True, style="g")

plt.style.use("seaborn-deep")
plt.suptitle("Album Ratings & Freq by Year", fontsize=24)
plt.xlabel("# of Albums", fontsize=20)
plt.ylabel("Avg Album Rating", fontsize=20)
# Out:
# Text(0, 0.5, 'Avg Album Rating')
